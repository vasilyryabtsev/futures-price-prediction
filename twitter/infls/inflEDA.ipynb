# %%
import pandas as pd
from nltk.tokenize import TweetTokenizer
from string import punctuation
from nltk.corpus import stopwords
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns
import regex as re
from sklearn.base import BaseEstimator, TransformerMixin

# %%
df = pd.read_csv('infl_tweets.csv', index_col=0)
df
# Out:
#             username                 name  \
# 0         davidfaber          David Faber
# 1         davidfaber          David Faber
# 2         davidfaber          David Faber
# 3         davidfaber          David Faber
# 4         davidfaber          David Faber
# ...              ...                  ...
# 14021  muddywatersre  MuddyWatersResearch
# 14022  muddywatersre  MuddyWatersResearch
# 14023  muddywatersre  MuddyWatersResearch
# 14024  muddywatersre  MuddyWatersResearch
# 14025  muddywatersre  MuddyWatersResearch
#
#                                                     text lang   in_reply_to  \
# 0      LVMH sales not good led by 5% decline in Fashi...   en           NaN
# 1      NYC losing another iconic restaurant: The 21 C...   en           NaN
# 2      ⁦@DivesTech⁩ always brightens our day. https:/...   en           NaN
# 3      Statement from PIF on PGA Commissioner Monahan...   en           NaN
# 4      Steve Cohen has entered exclusive negotiations...   en           NaN
# ...                                                  ...  ...           ...
# 14021  @CfaRoark @_KarlHungus_ @CliffordAsness I don’...   en  1.811785e+18
# 14022  @_KarlHungus_ @CliffordAsness I’m not arguing ...   en  1.811781e+18
# 14023  @CliffordAsness Biden showed a detailed, impre...   en  1.811771e+18
# 14024  I’ll be on @BloombergTV OpenInterest at 10 am ...   en           NaN
# 14025  @John_Hempton Frankly, I’m more depressed by n...   en  1.811332e+18
#
#        is_quote_status  retweeted_tweet  possibly_sensitive  favorited  \
# 0                False              NaN                 NaN      False
# 1                False              NaN                 0.0      False
# 2                False              NaN                 0.0      False
# 3                False              NaN                 0.0      False
# 4                False              NaN                 NaN      False
# ...                ...              ...                 ...        ...
# 14021            False              NaN                 NaN      False
# 14022            False              NaN                 NaN      False
# 14023            False              NaN                 NaN      False
# 14024            False              NaN                 NaN      False
# 14025            False              NaN                 NaN      False
#
#                             date  ...  view_count  view_count_state  \
# 0      2024-10-15 16:13:15+00:00  ...     15275.0  EnabledWithCount
# 1      2020-12-11 21:02:46+00:00  ...         NaN           Enabled
# 2      2023-08-29 14:43:53+00:00  ...     39816.0  EnabledWithCount
# 3      2023-06-14 14:01:05+00:00  ...     27073.0  EnabledWithCount
# 4      2020-08-29 01:53:26+00:00  ...         NaN           Enabled
# ...                          ...  ...         ...               ...
# 14021  2024-07-12 15:55:29+00:00  ...       194.0  EnabledWithCount
# 14022  2024-07-12 15:16:05+00:00  ...       300.0  EnabledWithCount
# 14023  2024-07-12 15:10:09+00:00  ...      1713.0  EnabledWithCount
# 14024  2024-07-12 12:44:53+00:00  ...     15938.0  EnabledWithCount
# 14025  2024-07-11 13:01:44+00:00  ...      1787.0  EnabledWithCount
#
#        retweet_count  place is_translatable  edits_remaining  has_card  \
# 0                  5    NaN           False              5.0     False
# 1                791    NaN           False              5.0     False
# 2                  8    NaN           False              5.0     False
# 3                  4    NaN           False              5.0     False
# 4               1059    NaN           False              5.0     False
# ...              ...    ...             ...              ...       ...
# 14021              0    NaN           False              5.0     False
# 14022              0    NaN           False              5.0     False
# 14023              0    NaN           False              5.0     False
# 14024              2    NaN           False              5.0     False
# 14025              1    NaN           False              5.0     False
#
#        thumbnail_title  urls  hashtags
# 0                  NaN    []        []
# 1                  NaN    []        []
# 2                  NaN    []        []
# 3                  NaN    []        []
# 4                  NaN    []        []
# ...                ...   ...       ...
# 14021              NaN    []        []
# 14022              NaN    []        []
# 14023              NaN    []        []
# 14024              NaN    []        []
# 14025              NaN    []        []
#
# [11820 rows x 23 columns]

# %% [markdown]
# ### Описание атрибутов ###
# - **username** - Username
# - **name** - Author of the tweet
# - **text** - The full text of the tweet
# - **lang** - The language of the tweet
# - **in_reply_to** - The tweet ID this tweet is in reply to, if any
# - **is_quote_status** - Indicates if the tweet is a quote status
# - **retweeted_tweet** - The Tweet being retweeted (if any)
# - **possibly_sensitive** - Indicates if the tweet content may be sensitive
# - **favorited** - Indicates if the tweet is favorited
# - **date** - The date and time when the tweet was created
# - **quote_count** - The count of quotes for the tweet
# - **reply_count** - The count of replies to the tweet
# - **favorite_count** - The count of favorites or likes for the tweet
# - **view_count** - The count of views
# - **view_count_state** - The state of the tweet views
# - **retweet_count** - The count of retweets for the tweet
# - **place** - The location associated with the tweet
# - **is_translatable** - Indicates if the tweet is translatable
# - **edits_remaining** - The remaining number of edits allowed for the tweet
# - **has_card** - Indicates if the tweet contains a card
# - **thumbnail_title** - The title of the webpage displayed inside the tweet’s card
# - **urls** - Information about URLs contained in the tweet
# - **hashtags** - Hashtags included in the tweet text

# %%
df = df.drop(['name', 'place', 'username'], axis=1)

# %% [markdown]
# ### Создание атрибута ticker ###

# %% [markdown]
# Для нахождения тикера в тексте можно воспользоваться предобученной моделью Jean-Baptiste/roberta-ticker, но у нее есть один существенный недостаток - если в тексте упомянут более чем один тикер, модель его не находит.

# %%
# from transformers import AutoTokenizer, AutoModelForTokenClassification

# tokenizer = AutoTokenizer.from_pretrained("Jean-Baptiste/roberta-ticker")
# model = AutoModelForTokenClassification.from_pretrained("Jean-Baptiste/roberta-ticker")

# from transformers import pipeline

# nlp = pipeline('ner', model=model, tokenizer=tokenizer, aggregation_strategy="simple")

# %%
# df.loc[3]['text']

# %%
# nlp(df.loc[3]['text'])

# %% [markdown]
# Найдем тикер с помощью регулярного выражения.
#
# В твитах компания не всегда упомянается через тикер. Иногда можно встретить полное название компании или же ее юзернейм. Исходя из этого, лучше обрабатывать все возможное варианты упоминаний компании, но в этом подходе есть своя сложность, заключающаяся в том, что наименования компании приходится вводить вручную.

# %%
# Списки тикеров
LIST_OF_TICKERS_1 = ['AAPL','META', 'NVDA', 'AMD', 'GOOG', 'XOM', 'MCD', 'KO', 'PFE', 'PG']
LIST_OF_TICKERS_2 = ['MSFT', 'AMZN', 'TSLA', 'GOOGL', 'JPM', 'JNJ', 'V', 'CMCSA', 'PEP', 'T', 'CSCO', 'DIS', 'NKE', 'VZ', 'HD', 'UNH', 'CRM', 'NFLX', 'INTC', 
                     'BA', 'MRK', 'LMT', 'GILD', 'SBUX']
LIST_OF_TICKERS_3 = ['AMGN', 'IBM', 'HON', 'PYPL', 'LRCX', 'MDLZ', 'BKNG', 'FDX', 'EOG', 'CIM', 'DVN', 'MPC', 'CHK', 
                     'RRC', 'NOG', 'ADBE', 'CAT', 'QCOM']
LIST_OF_TICKERS_4 = ["VRTX", "ETN", "BSX", "MDT", "ADI", "ANET", "PANW", "ADP", "KLAC", "BUD", "DE", "MELI", 
                      "SHOP", "FI", "BMY", "SO", "SHW", "DUK", "MAR", "DHI", "MRVL", "APD"]
LIST_OF_TICKERS_5 = ["CL", "WM", "SNPS", "SCCO", "ZTS", "APH", "DELL", "CTAS", "PH", "CMG", "ITW", "TGT", "MSI", "MCK", 
                     "ECL", "CSX", "CRWD", "ORLY", "CARR", "FCX", "SLB", "EPD", "CEG"]
LIST_OF_TICKERS_6 = ["NEM", "GM", "F", "NSC", "HLT", "AZO", "DASH", "AEP", "SRE", "LEN", "PCAR", "GEV", "CHTR", "WCN", "GWW", 
                      "D", "KMI", "PAYX", "STZ", "ODFL", "KHC", "FERG"]

def read_file(path):
    '''
    Возвращает список списков слов для каждой строки из файла.
    '''
    with open(path, mode='r') as file:
        return [line.split() for line in file.readlines()]
    
read_file('../comps/comp_usernames_1')

# Список списков наименований для тикеров (первый элемент в каждом списке - наименование тикера)
TICKERS = read_file('../comps/comp_usernames_1') + read_file('../comps/comp_usernames_2') + [[ticker] for ticker in LIST_OF_TICKERS_3] + [[ticker] for ticker in LIST_OF_TICKERS_4] + [[ticker] for ticker in LIST_OF_TICKERS_5] + [[ticker] for ticker in LIST_OF_TICKERS_6]

def is_ticker(x, ticker):
    '''
    Проверка на тикер.
    '''
    prog = re.compile(f'(?<!\S)\$?{ticker}(?!\S)')
    res = prog.findall(x)
    return len(res) != 0

df['ticker'] = [[] for _ in range(df.shape[0])]

for names in TICKERS:
    for name in names:
        df['ticker'] = df.apply(lambda x: x['ticker'] + [names[0]] if is_ticker(x['text'], name) else x['ticker'], axis=1)
    
df['ticker'] = df['ticker'].apply(lambda x: None if len(x) == 0 else x)
df = df.explode('ticker')
df = df.dropna(subset=['ticker'])
df = df.reset_index().drop('index', axis=1)
df['ticker'] = df['ticker'].apply(lambda x: x[1:] if '$' in x else x)

# %% [markdown]
# Датасет с размеченными тикерами:

# %%
df
# Out:
#                                                   text lang   in_reply_to  \
# 0    The chance of $MSFT winning an  appeal of the ...   en           NaN
# 1    We love and appreciate all the volunteers at t...   en           NaN
# 2    Today walking the lab on the NJ beach - tomorr...   en           NaN
# 3    Today walking the lab on the NJ beach - tomorr...   en           NaN
# 4    Good Morning from a dog walk on the $NVDA resc...   en           NaN
# ..                                                 ...  ...           ...
# 523  Autonomy takes center stage in this quarter's ...   en           NaN
# 524  Had to eat McDonalds over Wendy's this morning...   en           NaN
# 525                               $BA big equity raise   en           NaN
# 526  $JPM gives the BTC miners 9 months to get a de...   en           NaN
# 527  @StevenWalkerCFA @BillAckman Yes, dropping CFA...   en  1.827039e+18
#
#      is_quote_status  retweeted_tweet  possibly_sensitive  favorited  \
# 0              False              NaN                 0.0      False
# 1              False              NaN                 0.0      False
# 2              False              NaN                 0.0      False
# 3              False              NaN                 0.0      False
# 4              False              NaN                 0.0      False
# ..               ...              ...                 ...        ...
# 523            False              NaN                 NaN      False
# 524            False              NaN                 0.0      False
# 525            False              NaN                 NaN      False
# 526            False              NaN                 0.0      False
# 527            False              NaN                 NaN      False
#
#                           date  quote_count  reply_count  ...  view_count  \
# 0    2023-04-26 12:23:58+00:00            1           43  ...    113387.0
# 1    2024-05-06 13:54:43+00:00            0            0  ...       707.0
# 2    2024-05-08 13:11:46+00:00            0            0  ...       702.0
# 3    2024-05-08 13:11:46+00:00            0            0  ...       702.0
# 4    2024-05-05 13:56:44+00:00            0            2  ...       934.0
# ..                         ...          ...          ...  ...         ...
# 523  2024-10-25 21:04:57+00:00            0            0  ...      6220.0
# 524  2024-09-23 14:04:14+00:00            0            9  ...     18324.0
# 525  2024-10-28 10:51:25+00:00            0            0  ...      1021.0
# 526  2024-10-24 13:17:26+00:00            0            0  ...      1071.0
# 527  2024-08-23 18:13:51+00:00            0            1  ...       106.0
#
#      view_count_state retweet_count  is_translatable  edits_remaining  \
# 0    EnabledWithCount            19            False              5.0
# 1    EnabledWithCount             1            False              5.0
# 2    EnabledWithCount             0            False              5.0
# 3    EnabledWithCount             0            False              5.0
# 4    EnabledWithCount             0            False              5.0
# ..                ...           ...              ...              ...
# 523  EnabledWithCount             0            False              5.0
# 524  EnabledWithCount             2            False              5.0
# 525  EnabledWithCount             0            False              5.0
# 526  EnabledWithCount             0            False              5.0
# 527  EnabledWithCount             0            False              5.0
#
#      has_card                                    thumbnail_title  \
# 0       False                                                NaN
# 1       False                                                NaN
# 2       False                                                NaN
# 3       False                                                NaN
# 4       False                                                NaN
# ..        ...                                                ...
# 523      True                                                NaN
# 524     False                                                NaN
# 525     False                                                NaN
# 526      True  JPMorgan: Bitcoin miners have nine-month windo...
# 527     False                                                NaN
#
#                                                   urls hashtags ticker
# 0                                                   []       []   MSFT
# 1                                                   []       []   NVDA
# 2                                                   []       []   META
# 3                                                   []       []   NVDA
# 4                                                   []       []   NVDA
# ..                                                 ...      ...    ...
# 523                                                 []       []   TSLA
# 524                                                 []       []    MCD
# 525                                                 []       []     BA
# 526  [{'display_url': 'datacenterdynamics.com/en/ne...       []    JPM
# 527                                                 []       []      D
#
# [528 rows x 21 columns]

# %% [markdown]
# ### Предобработка данных ###

# %%
df.describe()
# Out:
#         in_reply_to  retweeted_tweet  possibly_sensitive  quote_count  \
# count  1.290000e+02              0.0               299.0   528.000000
# mean   1.668378e+18              NaN                 0.0     7.064394
# std    1.848504e+17              NaN                 0.0    60.853665
# min    7.851227e+17              NaN                 0.0     0.000000
# 25%    1.533059e+18              NaN                 0.0     0.000000
# 50%    1.697258e+18              NaN                 0.0     0.000000
# 75%    1.829605e+18              NaN                 0.0     1.000000
# max    1.851577e+18              NaN                 0.0  1263.000000
#
#        reply_count  favorite_count    view_count  retweet_count  \
# count   528.000000      528.000000  4.260000e+02     528.000000
# mean     14.903409      218.287879  4.818457e+04      27.392045
# std      74.320248     1334.763003  2.350530e+05     189.626687
# min       0.000000        0.000000  2.200000e+01       0.000000
# 25%       0.000000        3.000000  1.901750e+03       0.000000
# 50%       1.000000       14.000000  6.255000e+03       1.000000
# 75%       5.000000       47.500000  2.451175e+04       8.000000
# max    1532.000000    22396.000000  4.559190e+06    3753.000000
#
#        edits_remaining
# count            524.0
# mean               5.0
# std                0.0
# min                5.0
# 25%                5.0
# 50%                5.0
# 75%                5.0
# max                5.0

# %%
df = df.drop(['retweeted_tweet', 'possibly_sensitive'], axis=1)

# %%
df.columns
# Out:
# Index(['text', 'lang', 'in_reply_to', 'is_quote_status', 'favorited', 'date',
#        'quote_count', 'reply_count', 'favorite_count', 'view_count',
#        'view_count_state', 'retweet_count', 'is_translatable',
#        'edits_remaining', 'has_card', 'thumbnail_title', 'urls', 'hashtags',
#        'ticker'],
#       dtype='object')

# %%
df[['quote_count', 'reply_count', 'favorite_count', 'view_count', 'retweet_count']].corr()
# Out:
#                 quote_count  reply_count  favorite_count  view_count  \
# quote_count        1.000000     0.963951        0.838064    0.981210
# reply_count        0.963951     1.000000        0.801770    0.983968
# favorite_count     0.838064     0.801770        1.000000    0.931289
# view_count         0.981210     0.983968        0.931289    1.000000
# retweet_count      0.742339     0.667773        0.963319    0.926267
#
#                 retweet_count
# quote_count          0.742339
# reply_count          0.667773
# favorite_count       0.963319
# view_count           0.926267
# retweet_count        1.000000

# %%
df = df.drop(['quote_count', 'reply_count', 'favorite_count', 'retweet_count'], axis=1)

# %%
df.describe(include='object')
# Out:
#                                                      text lang  \
# count                                                 528  528
# unique                                                404    8
# top     It's a MEGA earnings week, with Alphabet $GOOG...   en
# freq                                                    7  519
#
#                              date  view_count_state  \
# count                         528               528
# unique                        402                 2
# top     2024-10-29 18:10:00+00:00  EnabledWithCount
# freq                            7               426
#
#                                           thumbnail_title urls hashtags ticker
# count                                                  76  528      528    528
# unique                                                 67  132       15     63
# top     527: Zuck Trying to Osborne Apple, Orion AR, S...   []       []   NVDA
# freq                                                    3  351      510     83

# %%
df.isna().sum()
# Out:
# text                  0
# lang                  0
# in_reply_to         399
# is_quote_status       0
# favorited             0
# date                  0
# view_count          102
# view_count_state      0
# is_translatable       0
# edits_remaining       4
# has_card              0
# thumbnail_title     452
# urls                  0
# hashtags              0
# ticker                0
# dtype: int64

# %%
# дата и время
df['date'] = pd.to_datetime(df['date'])

df['day'] = df['date'].apply(lambda x: x.day)
df['month'] = df['date'].apply(lambda x: x.month)
df['year'] = df['date'].apply(lambda x: x.year)

# заполнение пропусков
df['thumbnail_title'] = df['thumbnail_title'].fillna('')

# %% [markdown]
# ### Текстовые признаки ###

# %%
tw = TweetTokenizer()

special_symbols = ['“', '’', '”', '…', '...']
noise = stopwords.words("english") + list(punctuation) + special_symbols

def remove_stop_words(x):
    res = []
    for token in tw.tokenize(x.lower()):
        if token not in noise:
            res.append(token)
    return res

def process_text_att(data, col_name, top_count=25):
    word_counts = data[col_name].apply(remove_stop_words).explode().value_counts()[:top_count]
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(word_counts.to_dict())
    
    plt.figure(figsize=(12, 6))
    sns.barplot(x=word_counts.values, y=word_counts.index, palette='viridis')
    plt.xlabel('Frequency')
    plt.ylabel('Words')
    plt.title(f'Top {top_count} Most Frequent Words from {data[col_name].name}')
    plt.show()
    
    plt.figure(figsize=(12, 6))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    
process_text_att(df, 'text')
process_text_att(df, 'thumbnail_title')
# Out:
# /tmp/ipykernel_251145/3537336777.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=word_counts.values, y=word_counts.index, palette='viridis')
# /tmp/ipykernel_251145/3537336777.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=word_counts.values, y=word_counts.index, palette='viridis')

# %%
df['hashtags'].unique()
# Out:
# array(['[]', "['dividendstocks']", "['ElonMusk']", "['Sahm']",
#        "['Lennar', 'Florida']", "['AI']", "['fridaynightdump']",
#        "['Nike']", "['toosoon']", "['IBM', 'Earnings', 'Tech']",
#        "['AI', 'StockMarket', 'investing']",
#        "['Investing', 'DowJones', 'StockMarket']",
#        "['StockMarket', 'FedRateCut', 'TechStocks']",
#        "['Microsoft', 'Dividends', 'StockMarket']",
#        "['NVIDIA', 'StockMarket', 'Investing']"], dtype=object)

# %% [markdown]
# Преобразуем список хештегов в формат строки

# %%
df['hashtags'] = df['hashtags'].apply(lambda x: ' '.join(eval(x)))

# %%
process_text_att(df, 'hashtags')
# Out:
# /tmp/ipykernel_251145/3537336777.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=word_counts.values, y=word_counts.index, palette='viridis')

# %%
df[df['thumbnail_title'] == ''].shape
# Out:
# (452, 18)

# %%
df[df['hashtags'] == ''].shape
# Out:
# (510, 18)

# %%
df['text'] = df['text'] + ' ' + df['thumbnail_title'] + ' ' + df['hashtags']
df = df.drop(['thumbnail_title', 'hashtags'], axis=1)

# %% [markdown]
# ### Тикеры самых упомянаемых компаний ###

# %%
ticker_count = df['ticker'].value_counts()[:25]

plt.figure(figsize=(12, 6))
sns.barplot(x=ticker_count.values, y=ticker_count.index, palette='viridis')
plt.xlabel('Frequency')
plt.ylabel('Tickers')
plt.title('Top 25 Most Frequent Tickers')
plt.show()
# Out:
# /tmp/ipykernel_251145/265398946.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ticker_count.values, y=ticker_count.index, palette='viridis')

# %% [markdown]
# ### date ###

# %%
def create_hist(x, x_bins=None):  
    fig, ax = plt.subplots()
       
    ax.hist(x, edgecolor='black', bins=x_bins)    
      
    ax.grid(True, which='both', axis='y', linestyle='--', color='gray', alpha=0.7)    
    ax.set_xlabel(x.name)   
    ax.set_title(f'tweets - {x.name}')    
    plt.show()
    
create_hist(df['year'])

# %% [markdown]
# ### text ###

# %% [markdown]
# Процент твитов с упомянанием нескольких компаний от общего кол-ва твитов:

# %%
(df.shape[0] - df['text'].unique().shape[0]) / df.shape[0]
# Out:
# 0.23484848484848486

# %% [markdown]
# ### lang ###

# %% [markdown]
# Уникальные значения:

# %%
df['lang'].unique()
# Out:
# array(['en', 'lv', 'sv', 'qct', 'es', 'fr', 'und', 'qme'], dtype=object)

# %%
for lang in df['lang'].unique():
    text_sample = df[df['lang'] == lang].iloc[0]['text']
    print(f'{lang = }: {text_sample}')
# Out:
# lang = 'en': The chance of $MSFT winning an  appeal of the negative ruling from the CMA are exceedingly slim. Per UBS, the Competition Appeal Tribunal that would hear an appeal has not ruled in favor of merging parties for years. Appeal could also take a year.Getting very close to "all dead". https://t.co/3bGHnuM1b7
# lang = 'lv': Tesla, $TSLA unveils "Robovan" https://t.co/2WipLfdtIE
# lang = 'sv': @asharoraa meta dinner!
# lang = 'qct': $GOOG
# lang = 'es': $NFLX slide - consolidation in Media Landscape https://t.co/wYOH2IWrqE
# lang = 'fr': Chart crime nomination - $T https://t.co/iNEK4e0dS6
# lang = 'und': $CMG 2016
# lang = 'qme': 🤔
#
# $SBUX $CMG

# %% [markdown]
# Кодировка языков официального API твитера https://developer.x.com/en/docs/x-for-websites/supported-languages не совпадает с кодировкой из библиотеки Twikit, с помощью которой были собранны данные.
#
# В документации библиотеки Twikit, мне не удалось найти информации о кодировки языков, поэтому я решил убрать признак lang из дата сета, с учетом того, что судя по всему большинство данных сокращения не относятся к языкам или же они все-таки соответсвуют кодировки языков, но по неизвестной мне ошибке выводятся неккорректно.
#
# Далее примем, что все твиты написаны на английском языке. Это допущение можно сделать, поскольку данные собраны из англоязычных источников.

# %%
df = df.drop('lang', axis=1)

# %% [markdown]
# ### in_reply_to ###

# %% [markdown]
# Заменем признак in_reply_to на признак is_in_reply_to, указывающий на тип твита, является он ответом на другой твит или нет: ответ (1), иначе (0). В целом, было бы полезно узнать информацию о твите, на который был отправлен ответ, но данный датасет такой информации в себе не хранит.

# %%
df['is_in_reply_to'] = df['in_reply_to'].fillna(0).apply(lambda x: 0 if x == 0 else 1)
df.drop('in_reply_to', axis=1, inplace=True)

# %% [markdown]
# ### Обработка bool признаков ###

# %%
df.select_dtypes(include='bool').columns
# Out:
# Index(['is_quote_status', 'favorited', 'is_translatable', 'has_card'], dtype='object')

# %%
for col_name in df.columns:
    if df[col_name].dtypes == bool:
        df[col_name] = df[col_name].apply(int)

# %% [markdown]
# ### favorited ###

# %%
df['favorited'].unique()
# Out:
# array([0])

# %%
df.drop('favorited', axis=1, inplace=True)

# %% [markdown]
# ### _count признаки ###

# %% [markdown]
# view_count_state это категориальный признак, он показывает доступность получения информации о просмотренных твитах. Этот признак содержит только две категории, поэтому его можно перекодировать в бинарный - 1, если кол-во просмотров доступно; 0, если кол-во твитов недоступно.

# %%
df['is_view_count'] = df['view_count_state'].apply(lambda x: 1 if x == 'EnabledWithCount' else 0)
df = df.drop('view_count_state', axis=1)

# %% [markdown]
# Остальные _count признаки являеются численными.

# %%
create_hist(df['view_count'])

# %% [markdown]
# Рассмотрим распределение данных без выбросов:

# %%
create_hist(df[df['view_count'] <= df['view_count'].quantile(0.75)]['view_count'])

# %% [markdown]
# ### edits_remaining ###

# %%
df['edits_remaining'].unique()
# Out:
# array([ 5., nan])

# %% [markdown]
# Максимальное число оставшихся попыток равно 5.

# %%
df = df.drop('edits_remaining', axis=1)

# %% [markdown]
# ### urls ###

# %% [markdown]
# Упростим этот признак до проверки наличия ссылок в твите.

# %%
df['urls'].unique()
# Out:
# array(['[]',
#        "[{'display_url': 'spr.ly/6017UZthT', 'expanded_url': 'http://spr.ly/6017UZthT', 'url': 'https://t.co/LNuxk99HPs', 'indices': [134, 157]}]",
#        "[{'display_url': 'unusualwhales.com/hottest-contra…', 'expanded_url': 'https://unusualwhales.com/hottest-contracts?limit=250&hide_index_etf=true&vol_greater_oi=true&max_multileg_volume_ratio=0.05&order=bid_ask_prem&order_direction=desc&min_premium=250000', 'url': 'https://t.co/bzo7DltDVW', 'indices': [142, 165]}]",
#        "[{'display_url': 'unusualwhales.com/discord-bot', 'expanded_url': 'http://unusualwhales.com/discord-bot', 'url': 'https://t.co/lIDpnCxZai', 'indices': [140, 163]}]",
#        "[{'display_url': 'unusualwhales.com/news/google-go…', 'expanded_url': 'https://unusualwhales.com/news/google-googl-goog-is-funding-the-construction-of-7-small-nuclear-power-reactors-in-the-us-to-help-with-energy-needed-for-ai', 'url': 'https://t.co/jrvaIL7g5U', 'indices': [114, 137]}]",
#        "[{'display_url': 'trib.al/ok4s7jR', 'expanded_url': 'https://trib.al/ok4s7jR', 'url': 'https://t.co/cV93AoTuPF', 'indices': [55, 78]}]",
#        "[{'display_url': 'on.ft.com/3U3AdZt', 'expanded_url': 'https://on.ft.com/3U3AdZt', 'url': 'https://t.co/c27d8UcRah', 'indices': [66, 89]}]",
#        "[{'display_url': 'on.ft.com/3U5o5r3', 'expanded_url': 'https://on.ft.com/3U5o5r3', 'url': 'https://t.co/OL4yGcd0AR', 'indices': [76, 99]}]",
#        "[{'display_url': 'cnb.cx/3Y9gtF4', 'expanded_url': 'http://cnb.cx/3Y9gtF4', 'url': 'https://t.co/Z4FtYTQYv3', 'indices': [244, 267]}]",
#        "[{'display_url': 'cnbc.com/2024/10/14/goo…', 'expanded_url': 'https://www.cnbc.com/2024/10/14/google-inks-deal-with-nuclear-company-as-data-center-power-demand-surges.html?taid=670d6e1bf69a21000131cb17&utm_campaign=trueanthem&utm_medium=social&utm_source=twitter%7Cmain', 'url': 'https://t.co/vcEXk3CZhV', 'indices': [73, 96]}]",
#        "[{'display_url': 'link.chtbl.com/fast_money', 'expanded_url': 'https://link.chtbl.com/fast_money', 'url': 'https://t.co/2KdGymyRed', 'indices': [154, 177]}]",
#        "[{'display_url': 'cnbc.com/2024/10/14/nvi…', 'expanded_url': 'https://www.cnbc.com/2024/10/14/nvidia-shares-hit-a-record-as-chipmaker-market-cap-tops-3point4-trillion.html?taid=670d4f247bca9e0001215660&utm_campaign=trueanthem&utm_medium=social&utm_source=twitter%7Cmain', 'url': 'https://t.co/0wKWv2Fs16', 'indices': [78, 101]}]",
#        "[{'display_url': 'cnb.cx/3Y1KgQ3', 'expanded_url': 'http://cnb.cx/3Y1KgQ3', 'url': 'https://t.co/VnuWGqnchC', 'indices': [233, 256]}]",
#        "[{'display_url': 'link.chtbl.com/halftime_report', 'expanded_url': 'https://link.chtbl.com/halftime_report', 'url': 'https://t.co/I1PNHn6kQl', 'indices': [237, 260]}]",
#        "[{'display_url': 'cnb.cx/4gTypw2', 'expanded_url': 'http://cnb.cx/4gTypw2', 'url': 'https://t.co/OEcdhWfDFD', 'indices': [172, 195]}]",
#        "[{'display_url': 'cnbc.com/2024/10/14/nvi…', 'expanded_url': 'https://www.cnbc.com/2024/10/14/nvidia-shares-hit-a-record-as-chipmaker-market-cap-tops-3point4-trillion.html?taid=670d7a9118bdc00001f21e4f&utm_campaign=trueanthem&utm_medium=social&utm_source=twitter%7Cmain', 'url': 'https://t.co/281LNt013g', 'indices': [72, 95]}]",
#        "[{'display_url': 'link.chtbl.com/power_lunch', 'expanded_url': 'https://link.chtbl.com/power_lunch', 'url': 'https://t.co/WV081BM7DG', 'indices': [219, 242]}]",
#        "[{'display_url': 'on.wsj.com/40hPIBl', 'expanded_url': 'https://on.wsj.com/40hPIBl', 'url': 'https://t.co/ujhEuBJ0EE', 'indices': [116, 139]}, {'display_url': 'on.wsj.com/40hPIBl', 'expanded_url': 'https://on.wsj.com/40hPIBl', 'url': 'https://t.co/ujhEuBJ0EE', 'indices': [140, 163]}]",
#        "[{'display_url': 'on.wsj.com/4dLzu6v', 'expanded_url': 'https://on.wsj.com/4dLzu6v', 'url': 'https://t.co/EcAK310Vsr', 'indices': [240, 263]}]",
#        "[{'display_url': 'on.wsj.com/484mE1X', 'expanded_url': 'https://on.wsj.com/484mE1X', 'url': 'https://t.co/YgEmmpcOEa', 'indices': [104, 127]}]",
#        "[{'display_url': 'libertyrpf.com/p/529-anthropi…', 'expanded_url': 'https://www.libertyrpf.com/p/529-anthropic-ceo-on-ai-future-spacex', 'url': 'https://t.co/aKv5Auc3Pr', 'indices': [203, 226]}]",
#        "[{'display_url': 'libertyrpf.com/p/527-zuck-try…', 'expanded_url': 'https://www.libertyrpf.com/p/527-zuck-trying-to-osborne-apple', 'url': 'https://t.co/BUMbInbuJR', 'indices': [253, 276]}]",
#        "[{'display_url': 'wsj.com/articles/unite…', 'expanded_url': 'https://www.wsj.com/articles/unitedhealth-shares-dive-after-health-giant-says-2025-results-likely-to-fall-short-8a7ff76a', 'url': 'https://t.co/FIb7eDzJHF', 'indices': [88, 111]}]",
#        "[{'display_url': 'trib.al/QyHMVnB', 'expanded_url': 'https://trib.al/QyHMVnB', 'url': 'https://t.co/tzzvQIj1fw', 'indices': [168, 191]}]",
#        "[{'display_url': 'trib.al/zQMjzLh', 'expanded_url': 'https://trib.al/zQMjzLh', 'url': 'https://t.co/pmh8fgQ1Fw', 'indices': [230, 253]}]",
#        "[{'display_url': 'trib.al/ByYdTpD', 'expanded_url': 'https://trib.al/ByYdTpD', 'url': 'https://t.co/lNQYYhXHR5', 'indices': [59, 82]}]",
#        "[{'display_url': 'trib.al/Gxk6c76', 'expanded_url': 'https://trib.al/Gxk6c76', 'url': 'https://t.co/BWvAwISNn5', 'indices': [143, 166]}]",
#        "[{'display_url': 'trib.al/fADCF2b', 'expanded_url': 'https://trib.al/fADCF2b', 'url': 'https://t.co/Z48nOkdnTb', 'indices': [98, 121]}]",
#        "[{'display_url': 'open.substack.com/pub/johnhempto…', 'expanded_url': 'https://open.substack.com/pub/johnhempton/p/thinking-aloud-about-google-remedies?r=h85&utm_campaign=post&utm_medium=web&showWelcomeOnShare=true', 'url': 'https://t.co/z0TxIvERPi', 'indices': [56, 79]}]",
#        "[{'display_url': 'zerohedge.com/technology/sup…', 'expanded_url': 'https://www.zerohedge.com/technology/superhuman-nvidia-ceo-blown-away-after-musk-sets-100000-gpus-19-days', 'url': 'https://t.co/CgY93ceElz', 'indices': [79, 102]}]",
#        "[{'display_url': 'youtu.be/c7Maiq84GVQ', 'expanded_url': 'https://youtu.be/c7Maiq84GVQ', 'url': 'https://t.co/lqyMqUB6bL', 'indices': [178, 201]}, {'display_url': 'tinyurl.com/mr37hxk9', 'expanded_url': 'https://tinyurl.com/mr37hxk9', 'url': 'https://t.co/ireJSS6WoJ', 'indices': [213, 236]}, {'display_url': 'tinyurl.com/yckauw7u', 'expanded_url': 'https://tinyurl.com/yckauw7u', 'url': 'https://t.co/j8iJ9z7ObL', 'indices': [255, 278]}]",
#        "[{'display_url': 'youtu.be/YK2Be7LcaK8', 'expanded_url': 'https://youtu.be/YK2Be7LcaK8', 'url': 'https://t.co/ygPwjWMpn3', 'indices': [168, 191]}, {'display_url': 'tinyurl.com/5n7dmfxk', 'expanded_url': 'https://tinyurl.com/5n7dmfxk', 'url': 'https://t.co/FnJaXJPQeP', 'indices': [203, 226]}, {'display_url': 'tinyurl.com/yc88ndrb', 'expanded_url': 'https://tinyurl.com/yc88ndrb', 'url': 'https://t.co/c7GEpPEGT9', 'indices': [245, 268]}]",
#        "[{'display_url': 'youtu.be/0wQJ-D8W1Pg', 'expanded_url': 'https://youtu.be/0wQJ-D8W1Pg', 'url': 'https://t.co/V01WyFfWBQ', 'indices': [176, 199]}, {'display_url': 'tinyurl.com/surrealdb', 'expanded_url': 'https://tinyurl.com/surrealdb', 'url': 'https://t.co/TVdCDob268', 'indices': [211, 234]}, {'display_url': 'tinyurl.com/surrealdb-apple', 'expanded_url': 'https://tinyurl.com/surrealdb-apple', 'url': 'https://t.co/m9TQR4WY2G', 'indices': [253, 276]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/H4p1RcpfIn', 'indices': [198, 221]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/H4p1RcpNxV', 'indices': [133, 156]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/cQM6mJsDWm', 'indices': [285, 308]}]",
#        "[{'display_url': 'bespokepremium.com/interactive/po…', 'expanded_url': 'https://www.bespokepremium.com/interactive/posts/think-big-blog/the-closer-semis-ai-breakouts-positioning-10-14-24', 'url': 'https://t.co/1xd0fqDooz', 'indices': [197, 220]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/H4p1RcpNxV', 'indices': [189, 212]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/H4p1RcpfIn', 'indices': [258, 281]}]",
#        "[{'display_url': 'econ.st/4gSLpSB', 'expanded_url': 'https://econ.st/4gSLpSB', 'url': 'https://t.co/8cDNa31PxN', 'indices': [132, 155]}]",
#        "[{'display_url': 'cnb.cx/3r2NDXD', 'expanded_url': 'https://cnb.cx/3r2NDXD', 'url': 'https://t.co/meECZrlbpG', 'indices': [91, 114]}]",
#        "[{'display_url': 'cnb.cx/3r4P74n', 'expanded_url': 'https://cnb.cx/3r4P74n', 'url': 'https://t.co/IQVlrPAOIK', 'indices': [136, 159]}]",
#        "[{'display_url': 'spr.ly/6011ql0if', 'expanded_url': 'http://spr.ly/6011ql0if', 'url': 'https://t.co/tiw9OMqPmF', 'indices': [122, 145]}]",
#        "[{'display_url': 'spr.ly/6019qlGhc', 'expanded_url': 'http://spr.ly/6019qlGhc', 'url': 'https://t.co/gdEWQIpiCR', 'indices': [71, 94]}]",
#        "[{'display_url': 'unusualwhales.com/news/apple-aap…', 'expanded_url': 'https://unusualwhales.com/news/apple-aapl-could-suspend-production-of-the-vision-pro-as-soon-as-next-month-amid-weak-demand-per-the-information', 'url': 'https://t.co/BCyszrqYCV', 'indices': [222, 245]}]",
#        "[{'display_url': 'unusualwhales.com/news-feed', 'expanded_url': 'http://unusualwhales.com/news-feed', 'url': 'https://t.co/NZ42mMeaYO', 'indices': [70, 93]}]",
#        "[{'display_url': 'unusualwhales.com/discord-bot', 'expanded_url': 'http://unusualwhales.com/discord-bot', 'url': 'https://t.co/lIDpnCxZai', 'indices': [120, 143]}]",
#        "[{'display_url': 'unusualwhales.com/hottest-contra…', 'expanded_url': 'https://unusualwhales.com/hottest-contracts?limit=250&hide_index_etf=true&vol_greater_oi=true&max_multileg_volume_ratio=0.05&order=bid_ask_prem&order_direction=desc&min_premium=250000', 'url': 'https://t.co/bzo7Dlt66o', 'indices': [199, 222]}]",
#        "[{'display_url': 'unusualwhales.com/stock/SBUX/ove…', 'expanded_url': 'http://unusualwhales.com/stock/SBUX/overview', 'url': 'https://t.co/kDqiJX0tXH', 'indices': [179, 202]}]",
#        "[{'display_url': 'trib.al/9xElYCk', 'expanded_url': 'https://trib.al/9xElYCk', 'url': 'https://t.co/dNy03IPyNU', 'indices': [52, 75]}]",
#        "[{'display_url': 'trib.al/Hl7ZeJW', 'expanded_url': 'https://trib.al/Hl7ZeJW', 'url': 'https://t.co/RGxyEQJbYL', 'indices': [137, 160]}, {'display_url': 'trib.al/Hl7ZeJW', 'expanded_url': 'https://trib.al/Hl7ZeJW', 'url': 'https://t.co/RGxyEQJbYL', 'indices': [161, 184]}]",
#        "[{'display_url': 'trib.al/5lCqT0t', 'expanded_url': 'https://trib.al/5lCqT0t', 'url': 'https://t.co/ianRGzYuq0', 'indices': [65, 88]}, {'display_url': 'trib.al/5lCqT0t', 'expanded_url': 'https://trib.al/5lCqT0t', 'url': 'https://t.co/ianRGzYuq0', 'indices': [89, 112]}]",
#        "[{'display_url': 'on.ft.com/3YiXBnq', 'expanded_url': 'https://on.ft.com/3YiXBnq', 'url': 'https://t.co/LCON0iyUbS', 'indices': [64, 87]}]",
#        "[{'display_url': 'on.ft.com/48k3yoy', 'expanded_url': 'https://on.ft.com/48k3yoy', 'url': 'https://t.co/jYDO65pmNm', 'indices': [169, 192]}]",
#        "[{'display_url': 'theirrelevantinvestor.com/p/thoughts-sel…', 'expanded_url': 'https://www.theirrelevantinvestor.com/p/thoughts-selloff', 'url': 'https://t.co/a5vrtODTgU', 'indices': [154, 177]}]",
#        "[{'display_url': 'theirrelevantinvestor.com/p/nvidia-big-f…', 'expanded_url': 'https://www.theirrelevantinvestor.com/p/nvidia-big-fail', 'url': 'https://t.co/KzMIiEkDh0', 'indices': [145, 168]}]",
#        "[{'display_url': 'cnb.cx/3BVu2ka', 'expanded_url': 'http://cnb.cx/3BVu2ka', 'url': 'https://t.co/og9HZlo3e6', 'indices': [242, 265]}]",
#        "[{'display_url': 'cnb.cx/40dVvHX', 'expanded_url': 'http://cnb.cx/40dVvHX', 'url': 'https://t.co/Hjf5mz1Spj', 'indices': [251, 274]}]",
#        "[{'display_url': 'cnbc.com/2024/10/25/key…', 'expanded_url': 'https://www.cnbc.com/2024/10/25/keybanc-downgrades-apple-to-underweight-citing-iphone-sale-concerns-.html?taid=671b71837c34f40001d63425&utm_campaign=trueanthem&utm_medium=social&utm_source=twitter%7Cmain', 'url': 'https://t.co/7hzh2UZAkp', 'indices': [69, 92]}]",
#        "[{'display_url': 'cnbc.com/2023/10/24/how…', 'expanded_url': 'https://www.cnbc.com/2023/10/24/how-to-scrub-personal-information-from-google-search.html?utm_content=Main&utm_medium=Social&utm_source=twitter%7Cmain', 'url': 'https://t.co/FZjXuzpFpS', 'indices': [82, 105]}]",
#        "[{'display_url': 'cnbc.com/2024/10/25/app…', 'expanded_url': 'https://www.cnbc.com/2024/10/25/apple-returns-to-top-5-in-china-with-iphone-16-huawei-grows-faster.html?taid=671b60ec9303b30001fcf9e1&utm_campaign=trueanthem&utm_medium=social&utm_source=twitter%7Cmain', 'url': 'https://t.co/qZnNI9rxCb', 'indices': [92, 115]}]",
#        "[{'display_url': 'goldmansachs.com/briefings/?chl…', 'expanded_url': 'https://www.goldmansachs.com/briefings/?chl=og&plt=tw&cid=cb&agp=aat&cre=bq617&plc=sp&sit=sp', 'url': 'https://t.co/Z3tl5E6XT8', 'indices': [216, 239]}]",
#        "[{'display_url': 'x.com/Simosapien/sta…', 'expanded_url': 'https://x.com/Simosapien/status/1724220417106182205', 'url': 'https://t.co/BkEQ1JewHx', 'indices': [178, 201]}]",
#        "[{'display_url': 'theguardian.com/technology/202…', 'expanded_url': 'https://www.theguardian.com/technology/2022/dec/07/metaverse-slow-death-facebook-losing-100bn-gamble-virtual-reality-mark-zuckerberg', 'url': 'https://t.co/ooRVam0uDK', 'indices': [54, 77]}]",
#        "[{'display_url': 'theverge.com/2021/10/6/2271…', 'expanded_url': 'https://www.theverge.com/2021/10/6/22712927/facebook-instagram-teen-mental-health-research', 'url': 'https://t.co/f5CDy2ay5o', 'indices': [50, 73]}]",
#        "[{'display_url': 'businessinsider.com/facebook-blame…', 'expanded_url': 'https://www.businessinsider.com/facebook-blames-apple-10-billion-loss-ad-privacy-warning-2022-2#:~:text=Facebook%20stands%20to%20lose%20%2410,from%20tracking%20you%20across%20apps', 'url': 'https://t.co/f6BpjBuK2I', 'indices': [161, 184]}]",
#        "[{'display_url': 'wsj.com/articles/netfl…', 'expanded_url': 'https://www.wsj.com/articles/netflix-cuts-subscription-prices-in-over-30-countries-ae6d047c', 'url': 'https://t.co/bmQIYiMxYC', 'indices': [62, 85]}]",
#        "[{'display_url': 'findmevalue.net', 'expanded_url': 'http://www.findmevalue.net', 'url': 'https://t.co/m7tzdN97xI', 'indices': [34, 57]}]",
#        "[{'display_url': 'blog.umd.edu/davidkass/2016…', 'expanded_url': 'https://blog.umd.edu/davidkass/2016/10/23/ted-weschler-explains-berkshire-hathaways-investment-in-apple-to-german-magazine/', 'url': 'https://t.co/v8I04NSSs8', 'indices': [15, 38]}]",
#        "[{'display_url': 'deadline.com/2022/10/uk-hou…', 'expanded_url': 'https://deadline.com/2022/10/uk-households-cancel-streaming-services-to-cut-costs-1235146621/', 'url': 'https://t.co/QGSSs6UyKH', 'indices': [180, 203]}]",
#        "[{'display_url': 'lightreading.com/cable-tech/whe…', 'expanded_url': 'https://www.lightreading.com/cable-tech/where-does-cable-go-from-here/d/d-id/777465', 'url': 'https://t.co/egiqUtxkjF', 'indices': [257, 280]}]",
#        "[{'display_url': 'findmevalue.net', 'expanded_url': 'http://findmevalue.net', 'url': 'https://t.co/7yQEY1bjiG', 'indices': [62, 85]}]",
#        "[{'display_url': 'bit.ly/3NzRlmb', 'expanded_url': 'https://bit.ly/3NzRlmb', 'url': 'https://t.co/8ax2OwRLrC', 'indices': [244, 267]}]",
#        "[{'display_url': 'bit.ly/3XyrwJ5', 'expanded_url': 'https://bit.ly/3XyrwJ5', 'url': 'https://t.co/mojy7LJaLH', 'indices': [200, 223]}]",
#        "[{'display_url': 'bit.ly/3XyrwJ5', 'expanded_url': 'https://bit.ly/3XyrwJ5', 'url': 'https://t.co/mojy7LJaLH', 'indices': [240, 263]}]",
#        "[{'display_url': 'bit.ly/3XyrwJ5', 'expanded_url': 'https://bit.ly/3XyrwJ5', 'url': 'https://t.co/mojy7LJaLH', 'indices': [238, 261]}]",
#        "[{'display_url': 'bit.ly/3X7dXi8', 'expanded_url': 'https://bit.ly/3X7dXi8', 'url': 'https://t.co/V3kS2YtnNh', 'indices': [219, 242]}]",
#        "[{'display_url': 'nytimes.com/2024/09/20/cli…', 'expanded_url': 'https://www.nytimes.com/2024/09/20/climate/three-mile-island-reopening.html', 'url': 'https://t.co/9UlLymD3J2', 'indices': [74, 97]}]",
#        "[{'display_url': 'x.com/business/statu…', 'expanded_url': 'https://x.com/business/status/641681974709612544', 'url': 'https://t.co/UWGNFpE5DS', 'indices': [36, 59]}]",
#        "[{'display_url': 'sec.gov/ix?doc=/Archiv…', 'expanded_url': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/34088/000003408824000062/xom-20241017.htm', 'url': 'https://t.co/kqpqwVK5Ox', 'indices': [159, 182]}]",
#        "[{'display_url': 'footnoted.com/cutting-corner…', 'expanded_url': 'https://www.footnoted.com/cutting-corners-at-exxonmobil/', 'url': 'https://t.co/5WTHIJb9tK', 'indices': [153, 176]}]",
#        "[{'display_url': 'sec.gov/ix?doc=/Archiv…', 'expanded_url': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/320193/000114036124038403/ny20033611x2_8k.htm', 'url': 'https://t.co/1UyMRmZmhS', 'indices': [55, 78]}]",
#        "[{'display_url': 'nyti.ms/3I85UdB', 'expanded_url': 'https://nyti.ms/3I85UdB', 'url': 'https://t.co/WdPVcn4UtE', 'indices': [172, 195]}]",
#        "[{'display_url': 'search.chatgpt.com', 'expanded_url': 'http://search.chatgpt.com', 'url': 'https://t.co/6pS2dKMcj4', 'indices': [15, 38]}]",
#        "[{'display_url': 'libertyrpf.com/p/531-perplexi…', 'expanded_url': 'https://www.libertyrpf.com/p/531-perplexity-s-and-p-global-nvidia', 'url': 'https://t.co/iKAAvZxYzL', 'indices': [249, 272]}]",
#        "[{'display_url': 'cnbc.com/2024/10/28/for…', 'expanded_url': 'https://www.cnbc.com/2024/10/28/ford-motor-f-earnings-q3-2024.html', 'url': 'https://t.co/xjvI5X6F67', 'indices': [113, 136]}]",
#        "[{'display_url': 'ft.com/content/520bf8…', 'expanded_url': 'https://www.ft.com/content/520bf847-7346-442a-8f70-5c4680ae2886', 'url': 'https://t.co/KjzNsIZfVw', 'indices': [73, 96]}]",
#        "[{'display_url': 'wsj.com/articles/pfize…', 'expanded_url': 'https://www.wsj.com/articles/pfizers-activist-battle-might-fizzlebut-its-stock-probably-wont-a4576a25', 'url': 'https://t.co/3DBcjr69ZN', 'indices': [74, 97]}]",
#        "[{'display_url': 'cnbc.com/2024/10/23/ibm…', 'expanded_url': 'https://www.cnbc.com/2024/10/23/ibm-earnings-q3-2024.html', 'url': 'https://t.co/BgyGbaVjWE', 'indices': [71, 94]}]",
#        "[{'display_url': 'natesilver.net/p/trumps-domin…', 'expanded_url': 'https://www.natesilver.net/p/trumps-dominating-the-news-again?utm_source=post-email-title&publication_id=1198116&post_id=150843886&utm_campaign=email-post-title&isFreemail=true&token=eyJ1c2VyX2lkIjoyMjM0MywicG9zdF9pZCI6MTUwODQzODg2LCJpYXQiOjE3MzAxMjc5ODAsImV4cCI6MTczMjcxOTk4MCwiaXNzIjoicHViLTExOTgxMTYiLCJzdWIiOiJwb3N0LXJlYWN0aW9uIn0.e44k7aPkZAodEfIqGpvz1aI9IyZIQupeEcJKH751v80&r=h8n&triedRedirect=true&utm_medium=email', 'url': 'https://t.co/1tRpaUvvpY', 'indices': [105, 128]}]",
#        "[{'display_url': 'ft.com/content/39e245…', 'expanded_url': 'https://www.ft.com/content/39e2452b-8223-4919-89cf-799b90af447a', 'url': 'https://t.co/fXPjWRXQ2r', 'indices': [233, 256]}]",
#        "[{'display_url': 'trib.al/FOisAeC', 'expanded_url': 'https://trib.al/FOisAeC', 'url': 'https://t.co/XTkVw2DRi7', 'indices': [136, 159]}]",
#        "[{'display_url': 'trib.al/ZBeXBVm', 'expanded_url': 'https://trib.al/ZBeXBVm', 'url': 'https://t.co/BsfvXqxCIb', 'indices': [182, 205]}]",
#        "[{'display_url': 'zerohedge.com/personal-finan…', 'expanded_url': 'https://www.zerohedge.com/personal-finance/october-surprise-adp-employment-report-signals-six-sigma-beat-week-elections', 'url': 'https://t.co/i8SNxBktA5', 'indices': [89, 112]}]",
#        "[{'display_url': 'qz.com/apple-intellig…', 'expanded_url': 'https://qz.com/apple-intelligence-ai-iphone-beta-features-siri-users-1851684957', 'url': 'https://t.co/Tnvlpc6jxr', 'indices': [57, 80]}]",
#        "[{'display_url': 'thereformedbroker.com/2023/10/10/why…', 'expanded_url': 'https://thereformedbroker.com/2023/10/10/why-meta-is-in-the-fight-of-its-life-against-openai-and-apple/', 'url': 'https://t.co/x96NQa28MM', 'indices': [62, 85]}]",
#        "[{'display_url': 'thereformedbroker.com/2023/08/22/is-…', 'expanded_url': 'https://thereformedbroker.com/2023/08/22/is-nvidia-the-new-tesla/', 'url': 'https://t.co/JgipOKtxr3', 'indices': [25, 48]}]",
#        "[{'display_url': 'thereformedbroker.com/2023/08/21/app…', 'expanded_url': 'https://thereformedbroker.com/2023/08/21/apple-hits-big-oversold-levels/', 'url': 'https://t.co/9l2uhbxZm8', 'indices': [31, 54]}]",
#        "[{'display_url': 'on.wsj.com/4f569oV', 'expanded_url': 'https://on.wsj.com/4f569oV', 'url': 'https://t.co/TDecCgEGmv', 'indices': [185, 208]}]",
#        "[{'display_url': 'on.wsj.com/4fnNPHA', 'expanded_url': 'https://on.wsj.com/4fnNPHA', 'url': 'https://t.co/raW9pfT4cF', 'indices': [143, 166]}]",
#        "[{'display_url': 'on.wsj.com/3UmytL4', 'expanded_url': 'https://on.wsj.com/3UmytL4', 'url': 'https://t.co/t6SIpKj0OQ', 'indices': [137, 160]}]",
#        "[{'display_url': 'pocket-lint.com/watchos-11-is-…', 'expanded_url': 'https://www.pocket-lint.com/watchos-11-is-turning-the-apple-watch-into-a-garmin/', 'url': 'https://t.co/80gP7uxBnR', 'indices': [356, 379]}]",
#        "[{'display_url': 'apple.com/newsroom/2024/…', 'expanded_url': 'https://www.apple.com/newsroom/2024/06/watchos-11-brings-powerful-health-and-fitness-insights/', 'url': 'https://t.co/1w6GoBsY2x', 'indices': [671, 694]}, {'display_url': 'bgr.com/tech/move-over…', 'expanded_url': 'https://bgr.com/tech/move-over-garmin-messages-via-satellite-is-coming-in-ios-18/', 'url': 'https://t.co/FIRLcxi7JX', 'indices': [696, 719]}, {'display_url': 'apple.com/watchos/watcho…', 'expanded_url': 'https://www.apple.com/watchos/watchos-preview/', 'url': 'https://t.co/MtmZhtAFmN', 'indices': [721, 744]}]",
#        "[{'display_url': 'businesskorea.co.kr/news/articleVi…', 'expanded_url': 'https://www.businesskorea.co.kr/news/articleView.html?idxno=216039', 'url': 'https://t.co/ud44oP1QEg', 'indices': [483, 506]}]",
#        "[{'display_url': 'youtu.be/AJ2keSJzYyY?si…', 'expanded_url': 'https://youtu.be/AJ2keSJzYyY?si=9acFKcNNaswawq89&t=739', 'url': 'https://t.co/Hxv4LMA7ef', 'indices': [114, 137]}]",
#        "[{'display_url': 'youtu.be/2S3H0DKntNw?si…', 'expanded_url': 'https://youtu.be/2S3H0DKntNw?si=f_dW2GWGT2zM0jQp', 'url': 'https://t.co/M4hBaRPsKa', 'indices': [49, 72]}]",
#        "[{'display_url': 'ft.com/content/8896a8…', 'expanded_url': 'https://www.ft.com/content/8896a83a-74ac-49e5-9296-3545b1094919', 'url': 'https://t.co/frjDIyOgQt', 'indices': [91, 114]}]",
#        "[{'display_url': 'youtu.be/MEQu3Sgwjr8', 'expanded_url': 'https://youtu.be/MEQu3Sgwjr8', 'url': 'https://t.co/PotdFVAGRz', 'indices': [153, 176]}, {'display_url': 'tinyurl.com/mv9yufyh', 'expanded_url': 'https://tinyurl.com/mv9yufyh', 'url': 'https://t.co/BYxUuiR2WS', 'indices': [187, 210]}, {'display_url': 'tinyurl.com/2uzp2uup', 'expanded_url': 'https://tinyurl.com/2uzp2uup', 'url': 'https://t.co/BawC8XGMoc', 'indices': [229, 252]}]",
#        "[{'display_url': 'docs.google.com/forms/d/e/1FAI…', 'expanded_url': 'https://docs.google.com/forms/d/e/1FAIpQLSdwyKZvLNQmx1Hj-t2MiOVaNSvYzvCXTqHxvxnlyUdAQ-NEoA/viewform', 'url': 'https://t.co/2KUfmkwCfN', 'indices': [64, 87]}]",
#        "[{'display_url': 'docs.google.com/spreadsheets/d…', 'expanded_url': 'https://docs.google.com/spreadsheets/d/1LNorTrTeI3dK7uDOE91DCNOXIdW1UbFKDy1ozGNykY4/edit?usp=sharing', 'url': 'https://t.co/Lt2e4CjKvi', 'indices': [189, 212]}]",
#        "[{'display_url': 'bit.ly/MCDinvestorpre…', 'expanded_url': 'https://bit.ly/MCDinvestorpresentation', 'url': 'https://t.co/81CSm93OoD', 'indices': [220, 243]}]",
#        "[{'display_url': 'bloomberg.com/news/articles/…', 'expanded_url': 'https://www.bloomberg.com/news/articles/2022-04-22/mcdonald-s-is-targeted-in-sec-complaint-filed-by-humane-society?sref=taxRtTxi', 'url': 'https://t.co/H9wArDACvO', 'indices': [252, 275]}]",
#        "[{'display_url': 'businesswire.com/news/home/2022…', 'expanded_url': 'https://www.businesswire.com/news/home/20220421005377/en/Carl-C.-Icahn-Files-Definitive-Proxy-Statement-and-Issues-Open-Letter-to-Shareholders-of-McDonalds-Corporation', 'url': 'https://t.co/nXz0jx1Y0c', 'indices': [61, 84]}]",
#        "[{'display_url': 'thirdpointlimited.com/wp-content/upl…', 'expanded_url': 'https://thirdpointlimited.com/wp-content/uploads/2021/08/Third-Point-Q2-2021-Investor-Letter-TPIL.pdf', 'url': 'https://t.co/IzW574zOrm', 'indices': [75, 98]}]",
#        "[{'display_url': 'cnbc.com/video/2021/03/…', 'expanded_url': 'https://www.cnbc.com/video/2021/03/08/david-tepper-gets-bullish-on-stocks.html', 'url': 'https://t.co/OYAbRWAL0N', 'indices': [128, 151]}]",
#        "[{'display_url': 'valuewalk.com/ibm-stock-gets…', 'expanded_url': 'https://www.valuewalk.com/ibm-stock-gets-hammered-despite-eps-beat-and-strong-revenue/', 'url': 'https://t.co/DEZHL4VVKp', 'indices': [238, 261]}]",
#        "[{'display_url': 'valuewalk.com/nvidia-and-asm…', 'expanded_url': 'https://www.valuewalk.com/nvidia-and-asml-stocks-plunge-stoking-ai-bubble-fears/', 'url': 'https://t.co/vPYrSoAOS5', 'indices': [133, 156]}]",
#        "[{'display_url': 'valuewalk.com/the-top-3-stoc…', 'expanded_url': 'https://www.valuewalk.com/the-top-3-stocks-on-the-dow-jones-in-q3/', 'url': 'https://t.co/ZHlcsshbY1', 'indices': [153, 176]}]",
#        "[{'display_url': 'valuewalk.com/dow-jones-and-…', 'expanded_url': 'https://www.valuewalk.com/dow-jones-and-sp-500-soar-to-record-highs-on-rate-cut-rally/', 'url': 'https://t.co/dZqeGNNvhH', 'indices': [259, 282]}]",
#        "[{'display_url': 'valuewalk.com/microsoft-boos…', 'expanded_url': 'https://www.valuewalk.com/microsoft-boosts-dividends-and-launches-a-new-buyback-program/', 'url': 'https://t.co/DIu29NDd1m', 'indices': [222, 245]}]",
#        "[{'display_url': 'valuewalk.com/nvidia-stock-t…', 'expanded_url': 'https://www.valuewalk.com/nvidia-stock-time-to-get-risk-on-again/', 'url': 'https://t.co/pp3VWmqy2z', 'indices': [220, 243]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/H4p1RcpNxV', 'indices': [139, 162]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/H4p1RcpNxV', 'indices': [256, 279]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/cQM6mJs66O', 'indices': [289, 312]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/H4p1RcpfIn', 'indices': [180, 203]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/H4p1RcpNxV', 'indices': [210, 233]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/H4p1RcpfIn', 'indices': [184, 207]}]",
#        "[{'display_url': 'bespokepremium.com/interactive/po…', 'expanded_url': 'https://www.bespokepremium.com/interactive/posts/think-big-blog/its-a-mega-earnings-week', 'url': 'https://t.co/6uvblDjupB', 'indices': [196, 219]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/H4p1RcpfIn', 'indices': [219, 242]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/H4p1RcpfIn', 'indices': [188, 211]}]",
#        "[{'display_url': 'bespokepremium.com', 'expanded_url': 'http://bespokepremium.com', 'url': 'https://t.co/H4p1RcpNxV', 'indices': [264, 287]}]",
#        "[{'display_url': 'datacenterdynamics.com/en/news/jpmorg…', 'expanded_url': 'https://www.datacenterdynamics.com/en/news/jpmorgan-bitcoin-miners-have-nine-month-window-to-get-ai-data-center-deals/', 'url': 'https://t.co/RCjmcPrtZl', 'indices': [102, 125]}]"],
#       dtype=object)

# %%
df['urls'] = df['urls'].apply(lambda x: 1 if x != '[]' else 0)

# %% [markdown]
# ### Удаление признаков с одним значением ###

# %%
for col_name in df.columns:
    if df[col_name].unique().shape[0] == 1:
        df = df.drop(col_name, axis=1)
        print(f'{col_name} deleted')
# Out:
# is_translatable deleted

# %% [markdown]
# ### Добавление данных о котировках ###

# %%
qs0 = pd.read_csv('../../quotes/quotes.csv')
qs1 = pd.read_csv('../../quotes/quotes_08-11-2024.csv')
qs2 = pd.read_csv('../../quotes/quotes_08-11-2024_1.csv')

qs0 = qs0.drop(['Unnamed: 0', 'id'], axis=1).rename({'quote_date': 'date'}, axis=1)[qs1.columns]
qs = pd.concat([qs0, qs1, qs2])

qs['date'] = pd.to_datetime(qs['date'])
qs = qs.drop(['high', 'low', 'volume'], axis=1)
qs = qs.drop_duplicates().reset_index(drop='first')

qs.head()
# Out:
#         date    open   close ticker
# 0 2024-10-18  236.18  235.00   AAPL
# 1 2024-10-17  233.43  232.15   AAPL
# 2 2024-10-16  231.60  231.78   AAPL
# 3 2024-10-15  233.61  233.85   AAPL
# 4 2024-10-14  228.70  231.30   AAPL

# %%
def open_price(X, Q):
    '''
    Возвращает модифицированный датасет X c новыми 
    аттрибутами quote_date и open, полученными из
    датасета с котировками Q.
    
    open - цена открытия в день публикации или в 
    первый доступный день до этой даты
    
    quote_date - дата котировки 
    '''
    def func(x):
        '''
        Возвращает котировку, соответвующую 
        дате и тикеру из x. Если такой котировки
        нет, возвращается значение None
        '''
        current_date = str(x['date'].date())
        ticker_name = x['ticker']
        filtered = Q[(Q['date'] <= current_date) & (Q['ticker'] == ticker_name)].sort_values(by='date', ascending=False)
        if filtered.empty:
            return None
        return filtered.iloc[0]
        
    buf = X.apply(func, axis=1).rename({'date': 'quote_date',
                                        'open': 'open_last'},
                                       axis=1).drop(['close', 'ticker'], axis=1)
    
    return pd.concat([X, buf], axis=1)

# %%
df = open_price(df, qs)

# %%
def close_price(X, Q, days = 1):
    '''
    Возвращает модифицированный датасет X c новым 
    аттрибутом close_{days}_day_after, полученными из
    датасета с котировками Q. Этот атрибут содержит цену закрытия
    через days дней после публикации твита (отсчитывается от даты 
    последней котировки).
    '''
    def func(x):
        '''
        Возвращает котировку, соответвующую дате
        через days дней после даты последней котировки и тикеру из x. 
        Если такой котировки нет, возвращается значение None
        '''
        current_date = x['quote_date'].date()
        ticker_name = x['ticker']
        next_date = current_date + pd.to_timedelta(days, unit='d')
        filtered = Q[(Q['date'] >= str(next_date)) & (Q['ticker'] == ticker_name)].sort_values(by='date')
        if filtered.empty:
            return None
        return filtered.iloc[0]
    
    buf = X.apply(func, axis=1).rename({'close': f'close_{days}_day_after'},
                                       axis=1).drop(['open', 'ticker', 'date'], axis=1)
    
    return pd.concat([X, buf], axis=1)

# %%
df = close_price(df, qs, 1)
# df = close_price(df, qs, 3)
# df = close_price(df, qs, 7)

# %%
df
# Out:
#                                                   text  is_quote_status  \
# 0    The chance of $MSFT winning an  appeal of the ...                0
# 1    We love and appreciate all the volunteers at t...                0
# 2    Today walking the lab on the NJ beach - tomorr...                0
# 3    Today walking the lab on the NJ beach - tomorr...                0
# 4    Good Morning from a dog walk on the $NVDA resc...                0
# ..                                                 ...              ...
# 523  Autonomy takes center stage in this quarter's ...                0
# 524  Had to eat McDonalds over Wendy's this morning...                0
# 525                             $BA big equity raise                  0
# 526  $JPM gives the BTC miners 9 months to get a de...                0
# 527  @StevenWalkerCFA @BillAckman Yes, dropping CFA...                0
#
#                          date  view_count  has_card  urls ticker  day  month  \
# 0   2023-04-26 12:23:58+00:00    113387.0         0     0   MSFT   26      4
# 1   2024-05-06 13:54:43+00:00       707.0         0     0   NVDA    6      5
# 2   2024-05-08 13:11:46+00:00       702.0         0     0   META    8      5
# 3   2024-05-08 13:11:46+00:00       702.0         0     0   NVDA    8      5
# 4   2024-05-05 13:56:44+00:00       934.0         0     0   NVDA    5      5
# ..                        ...         ...       ...   ...    ...  ...    ...
# 523 2024-10-25 21:04:57+00:00      6220.0         1     0   TSLA   25     10
# 524 2024-09-23 14:04:14+00:00     18324.0         0     0    MCD   23      9
# 525 2024-10-28 10:51:25+00:00      1021.0         0     0     BA   28     10
# 526 2024-10-24 13:17:26+00:00      1071.0         1     1    JPM   24     10
# 527 2024-08-23 18:13:51+00:00       106.0         0     0      D   23      8
#
#      year  is_in_reply_to  is_view_count quote_date  open_last  \
# 0    2023               0              1 2023-04-26    296.700
# 1    2024               0              1 2024-05-06    893.900
# 2    2024               0              1 2024-05-08    463.500
# 3    2024               0              1 2024-05-08    894.825
# 4    2024               0              1 2024-05-03    877.890
# ..    ...             ...            ...        ...        ...
# 523  2024               0              1 2024-10-25    256.010
# 524  2024               0              1 2024-09-23    299.000
# 525  2024               0              1 2024-10-28    153.500
# 526  2024               0              1 2024-10-24    221.830
# 527  2024               1              1 2024-08-23     56.620
#
#      close_1_day_after
# 0               304.83
# 1               905.54
# 2               475.42
# 3               887.47
# 4               921.40
# ..                 ...
# 523             262.51
# 524             300.27
# 525             152.98
# 526             222.31
# 527              56.52
#
# [528 rows x 15 columns]

# %% [markdown]
# Проверка пропусков

# %%
df.isna().sum()
# Out:
# text                   0
# is_quote_status        0
# date                   0
# view_count           102
# has_card               0
# urls                   0
# ticker                 0
# day                    0
# month                  0
# year                   0
# is_in_reply_to         0
# is_view_count          0
# quote_date             0
# open_last              0
# close_1_day_after      1
# dtype: int64

# %%
df['view_count'].fillna(df['view_count'].median(), inplace=True)

# %%
df = df.dropna()
df = df.drop(['date', 'quote_date'], axis=1)

# %% [markdown]
# ### Создание таргета ###

# %%
class СlsTargetTransformer(BaseEstimator, TransformerMixin):
    '''
    Класс трансформера, создающего таргет для задачи классификации.
    Положительная категория задается через процент минимальной прибыли.
    '''
    def __init__(self, shift_percent=0):
        """
        Инициализация трансформера с гиперпараметрами.
        :param shift_percent: Порог положительной категории таргета в процентах (опционально).
        """
        self.shift_percent = shift_percent

    def transform(self, X):
        """
        Метод transform: применяет преобразование к данным.
        :param X: Входные данные.
        :return: Преобразованные данные.
        """
        X_copy = X.copy()

        # for k in [1, 3, 7]:
        for k in [1]:
            col_name = f'{k}_day_after'
            X_copy[col_name] = (X_copy[f'close_{k}_day_after'] / X_copy['open_last'] - 1) * 100 - self.shift_percent
            X_copy[col_name] = X_copy[col_name].apply(lambda x: 1 if x >= 0 else 0)

        # X_copy = X_copy.drop(['close_1_day_after', 'close_3_day_after', 'close_7_day_after', 'open_last'], axis=1)
        X_copy = X_copy.drop(['close_1_day_after', 'open_last'], axis=1)

        return X_copy

# %%
class_target_transformer = СlsTargetTransformer()

df0 = class_target_transformer.transform(df)

df0.head()
# Out:
#                                                 text  is_quote_status  \
# 0  The chance of $MSFT winning an  appeal of the ...                0
# 1  We love and appreciate all the volunteers at t...                0
# 2  Today walking the lab on the NJ beach - tomorr...                0
# 3  Today walking the lab on the NJ beach - tomorr...                0
# 4  Good Morning from a dog walk on the $NVDA resc...                0
#
#    view_count  has_card  urls ticker  day  month  year  is_in_reply_to  \
# 0    113387.0         0     0   MSFT   26      4  2023               0
# 1       707.0         0     0   NVDA    6      5  2024               0
# 2       702.0         0     0   META    8      5  2024               0
# 3       702.0         0     0   NVDA    8      5  2024               0
# 4       934.0         0     0   NVDA    5      5  2024               0
#
#    is_view_count  1_day_after
# 0              1            1
# 1              1            1
# 2              1            1
# 3              1            0
# 4              1            1

# %%
target_cols = ['1_day_after']

for col in target_cols:
    buf = df0[col].value_counts(normalize=True)
    print(buf.to_frame())
    print('-' * 25)
# Out:
#              proportion
# 1_day_after
# 1              0.531309
# 0              0.468691
# -------------------------

# %%
sns.pairplot(df0)

# %%
df0_corr = df0.select_dtypes(include='number').corr()
df0_corr
# Out:
#                  is_quote_status  view_count  has_card      urls       day  \
# is_quote_status         1.000000   -0.036747 -0.128893 -0.191448 -0.093742
# view_count             -0.036747    1.000000 -0.035659 -0.059316 -0.031578
# has_card               -0.128893   -0.035659  1.000000  0.574786  0.032426
# urls                   -0.191448   -0.059316  0.574786  1.000000  0.166683
# day                    -0.093742   -0.031578  0.032426  0.166683  1.000000
# month                   0.010701    0.092157  0.079975  0.214516  0.122123
# year                    0.030779    0.076977  0.131498  0.210753  0.093639
# is_in_reply_to         -0.113516   -0.089762 -0.075724 -0.208628 -0.126545
# is_view_count           0.032386    0.078446  0.123036  0.216182  0.073962
# 1_day_after             0.007541   -0.017405  0.038098  0.007715 -0.075659
#
#                     month      year  is_in_reply_to  is_view_count  \
# is_quote_status  0.010701  0.030779       -0.113516       0.032386
# view_count       0.092157  0.076977       -0.089762       0.078446
# has_card         0.079975  0.131498       -0.075724       0.123036
# urls             0.214516  0.210753       -0.208628       0.216182
# day              0.122123  0.093639       -0.126545       0.073962
# month            1.000000  0.353673       -0.285966       0.355198
# year             0.353673  1.000000       -0.181578       0.819162
# is_in_reply_to  -0.285966 -0.181578        1.000000      -0.201433
# is_view_count    0.355198  0.819162       -0.201433       1.000000
# 1_day_after      0.108945  0.152554       -0.040142       0.175108
#
#                  1_day_after
# is_quote_status     0.007541
# view_count         -0.017405
# has_card            0.038098
# urls                0.007715
# day                -0.075659
# month               0.108945
# year                0.152554
# is_in_reply_to     -0.040142
# is_view_count       0.175108
# 1_day_after         1.000000

# %%
sns.heatmap(df0_corr)
# Out:
# <Axes: >

# %%
df.to_csv('../tweets.csv')

# %% [markdown]
# ### Выводы ###

# %% [markdown]
# - Размеченный датасет получился слишком мальнький для обучения модели только на данных из твиттера. В текущем состоянии его можно использовать в качестве дополнительных данных для более объемной модели.
# - Проблема малого кол-ва объектов в дата сете связана в первую очередь с не самым оптимальным подходом для сбора данных из твитера. Так же это связано с недостатком наименований компаний на этапе выявления тикеров из уже собранных твитов.

# %% [markdown]
# ### Что можно исправить? ###

# %% [markdown]
# - Оптимизировать парсер
# - Добавить больше наименований компаний
